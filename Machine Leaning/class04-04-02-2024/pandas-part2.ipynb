# %%
import pandas as pd
import numpy as np

# %%
json_url = "https://api.github.com/repos/pandas-dev/pandas/issues"
dataFrame_Json = pd.read_json(json_url);
dataFrame_Json[["user"]]
# Out:
#                                                  user
# 0   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 1   {'login': 'jordan-d-murphy', 'id': 35613487, '...
# 2   {'login': 'noah-asing', 'id': 7989798, 'node_i...
# 3   {'login': 'jrmylow', 'id': 33999325, 'node_id'...
# 4   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 5   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6   {'login': 'koushik-rout-samsung', 'id': 146946...
# 7   {'login': 'LakshmanKishore', 'id': 61258323, '...
# 8   {'login': 'Jorewin', 'id': 56088851, 'node_id'...
# 9   {'login': 'gsehrlich', 'id': 11000354, 'node_i...
# 10  {'login': 'khider', 'id': 11758571, 'node_id':...
# 11  {'login': 'michaelquinn32', 'id': 3473921, 'no...
# 12  {'login': 'sfc-gh-aalam', 'id': 107440467, 'no...
# 13  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 14  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 15  {'login': 'steppi', 'id': 1953382, 'node_id': ...
# 16  {'login': 'celestinoxp', 'id': 41735311, 'node...
# 17  {'login': 'damianr13', 'id': 7912289, 'node_id...
# 18  {'login': 'yuanx749', 'id': 47032563, 'node_id...
# 19  {'login': 'maread99', 'id': 56914820, 'node_id...
# 20  {'login': 'PaleNeutron', 'id': 8296331, 'node_...
# 21  {'login': 'weltenseglr', 'id': 19477864, 'node...
# 22  {'login': 'wjandrea', 'id': 22385371, 'node_id...
# 23  {'login': 'tqa236', 'id': 25203655, 'node_id':...
# 24  {'login': 'tqa236', 'id': 25203655, 'node_id':...
# 25  {'login': 'bebach', 'id': 145982645, 'node_id'...
# 26  {'login': 'enryH', 'id': 2833836, 'node_id': '...
# 27  {'login': 'mtsokol', 'id': 8431159, 'node_id':...
# 28  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 29  {'login': 'lukemanley', 'id': 8519523, 'node_i...

# %%
type(dataFrame_Json)
# Out:
# pandas.core.frame.DataFrame

# %%
import requests
json_data = requests.get(json_url)

# %%
json_data
# Out:
# <Response [200]>

# %%
Json_via_request_AsList = json_data.json()

# %%
Json_via_request_AsList
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57241',
#   'id': 2116847445,
#   'node_id': 'PR_kwDOAA0YD85l7yjQ',
#   'number': 57241,
#   'title': 'DEPR: Remove sql.execute, *args/**kwargs in resample, unrecognized timezones',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 45,
#    'closed_issues': 151,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-02-04T05:21:06Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-04T03:07:01Z',
#   'updated_at': '2024-02-04T03:07:02Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57241',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57241',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57241.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57241.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57239',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57239/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57239/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57239/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57239',
#   'id': 2116792327,
#   'node_id': 'PR_kwDOAA0YD85l7mRn',
#   'number': 57239,
#   'title': 'DOC: fix PR02 errors in docstring for pandas.Series.rename_axis',
#   'user': {'login': 'jordan-d-murphy',
#    'id': 35613487,
#    'node_id': 'MDQ6VXNlcjM1NjEzNDg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613487?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jordan-d-murphy',
#    'html_url': 'https://github.com/jordan-d-murphy',
#    'followers_url': 'https://api.github.com/users/jordan-d-murphy/followers',
#    'following_url': 'https://api.github.com/users/jordan-d-murphy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jordan-d-murphy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jordan-d-murphy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jordan-d-murphy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jordan-d-murphy/orgs',
#    'repos_url': 'https://api.github.com/users/jordan-d-murphy/repos',
#    'events_url': 'https://api.github.com/users/jordan-d-murphy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jordan-d-murphy/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-02-04T01:19:50Z',
#   'updated_at': '2024-02-04T05:27:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57239',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57239',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57239.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57239.patch',
#    'merged_at': None},
#   'body': 'All PR02 Errors resolved in the following cases:\r\n\r\n1. scripts/validate_docstrings.py --format=actions --errors=PR02 pandas.Series.rename_axis\r\n2. scripts/validate_docstrings.py --format=actions --errors=PR02 pandas.DataFrame.rename_axis\r\n\r\nOUTPUT:\r\n\r\n1. scripts/validate_docstrings.py --format=actions --errors=PR02 pandas.Series.rename_axis\r\n```\r\n################################################################################\r\n################################## Validation ##################################\r\n################################################################################\r\n\r\n1 Errors found for `pandas.Series.rename_axis`:\r\n\tES01\tNo extended summary found\r\n```\r\n\r\n2. scripts/validate_docstrings.py --format=actions --errors=PR02 pandas.DataFrame.rename_axis\r\n```\r\n################################################################################\r\n################################## Validation ##################################\r\n################################################################################\r\n\r\n1 Errors found for `pandas.DataFrame.rename_axis`:\r\n\tES01\tNo extended summary found\r\n```\r\n\r\n\r\n- [x] xref https://github.com/pandas-dev/pandas/issues/57111\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57239/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57239/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57236',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57236/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57236/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57236/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57236',
#   'id': 2116744441,
#   'node_id': 'PR_kwDOAA0YD85l7beW',
#   'number': 57236,
#   'title': 'DOC: Clarifying brackets vs. parentheses',
#   'user': {'login': 'noah-asing',
#    'id': 7989798,
#    'node_id': 'MDQ6VXNlcjc5ODk3OTg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7989798?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/noah-asing',
#    'html_url': 'https://github.com/noah-asing',
#    'followers_url': 'https://api.github.com/users/noah-asing/followers',
#    'following_url': 'https://api.github.com/users/noah-asing/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/noah-asing/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/noah-asing/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/noah-asing/subscriptions',
#    'organizations_url': 'https://api.github.com/users/noah-asing/orgs',
#    'repos_url': 'https://api.github.com/users/noah-asing/repos',
#    'events_url': 'https://api.github.com/users/noah-asing/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/noah-asing/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-04T00:05:26Z',
#   'updated_at': '2024-02-04T06:09:03Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57236',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57236',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57236.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57236.patch',
#    'merged_at': None},
#   'body': '- [x] closes #56972\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit). (Doc edits only)\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions. (Doc edits only)\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature. (Doc edits only)\r\n\r\nIn addition to the clarification requested in #56972, I adjusted the language where square brackets were specified elsewhere in the documentation to match "square brackets ``[]``", with the exception of one file.\r\n\r\nIn the data subsetting tutorial guide (`doc/source/getting_started/intro_tutorials/03_subset_data.rst`),  square brackets are specified towards the beginning of the guide, and "selection brackets" was used elsewhere, often to specify outer vs. inner square brackets (i.e. `df[[\'ColA\', \'ColB\']]`)',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57236/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57236/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57235',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57235/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57235/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57235/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57235',
#   'id': 2116717762,
#   'node_id': 'PR_kwDOAA0YD85l7VXe',
#   'number': 57235,
#   'title': 'DOC: Updated docstring for set_option',
#   'user': {'login': 'jrmylow',
#    'id': 33999325,
#    'node_id': 'MDQ6VXNlcjMzOTk5MzI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33999325?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrmylow',
#    'html_url': 'https://github.com/jrmylow',
#    'followers_url': 'https://api.github.com/users/jrmylow/followers',
#    'following_url': 'https://api.github.com/users/jrmylow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrmylow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrmylow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrmylow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrmylow/orgs',
#    'repos_url': 'https://api.github.com/users/jrmylow/repos',
#    'events_url': 'https://api.github.com/users/jrmylow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrmylow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-02-03T23:42:37Z',
#   'updated_at': '2024-02-03T23:49:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57235',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57235',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57235.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57235.patch',
#    'merged_at': None},
#   'body': '- [X] closes #57148\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57235/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57235/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57233',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57233/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57233/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57233/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57233',
#   'id': 2116710632,
#   'node_id': 'PR_kwDOAA0YD85l7UKJ',
#   'number': 57233,
#   'title': 'REGR: Fix to_numpy conversion for arrow ea with float dtype given',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/116',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116/labels',
#    'id': 10403366,
#    'node_id': 'MI_kwDOAA0YD84Anr4m',
#    'number': 116,
#    'title': '2.2.1',
#    'description': 'on-merge: backport to 2.2.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 41,
#    'closed_issues': 69,
#    'state': 'open',
#    'created_at': '2024-01-11T01:47:31Z',
#    'updated_at': '2024-02-04T03:08:15Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-03T23:12:42Z',
#   'updated_at': '2024-02-04T00:07:55Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57233',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57233',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57233.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57233.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nxref #57121',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57233/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57233/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57231',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57231/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57231/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57231/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57231',
#   'id': 2116701137,
#   'node_id': 'PR_kwDOAA0YD85l7Sdw',
#   'number': 57231,
#   'title': 'DEPR: Remove Index type checking attributes',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1218227310,
#     'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index',
#     'name': 'Index',
#     'color': 'e99695',
#     'default': False,
#     'description': 'Related to the Index class or subclasses'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 45,
#    'closed_issues': 151,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-02-04T05:21:06Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-03T22:35:19Z',
#   'updated_at': '2024-02-04T02:42:18Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57231',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57231',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57231.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57231.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57231/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57231/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57226',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57226/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57226/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57226/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57226',
#   'id': 2116622677,
#   'node_id': 'PR_kwDOAA0YD85l7DRf',
#   'number': 57226,
#   'title': 'WEB: Using Bootstrap icon instead of font awesome icons',
#   'user': {'login': 'koushik-rout-samsung',
#    'id': 146946876,
#    'node_id': 'U_kgDOCMI7PA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146946876?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/koushik-rout-samsung',
#    'html_url': 'https://github.com/koushik-rout-samsung',
#    'followers_url': 'https://api.github.com/users/koushik-rout-samsung/followers',
#    'following_url': 'https://api.github.com/users/koushik-rout-samsung/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/koushik-rout-samsung/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/koushik-rout-samsung/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/koushik-rout-samsung/subscriptions',
#    'organizations_url': 'https://api.github.com/users/koushik-rout-samsung/orgs',
#    'repos_url': 'https://api.github.com/users/koushik-rout-samsung/repos',
#    'events_url': 'https://api.github.com/users/koushik-rout-samsung/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/koushik-rout-samsung/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-02-03T18:11:13Z',
#   'updated_at': '2024-02-03T21:53:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57226',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57226',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57226.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57226.patch',
#    'merged_at': None},
#   'body': 'Closes https://github.com/pandas-dev/pandas/issues/57165\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57226/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57226/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57223',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57223/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57223/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57223/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57223',
#   'id': 2116463548,
#   'node_id': 'PR_kwDOAA0YD85l6iHK',
#   'number': 57223,
#   'title': 'DOC: Replace pandas logo with a conditional image for light and dark …',
#   'user': {'login': 'LakshmanKishore',
#    'id': 61258323,
#    'node_id': 'MDQ6VXNlcjYxMjU4MzIz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61258323?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LakshmanKishore',
#    'html_url': 'https://github.com/LakshmanKishore',
#    'followers_url': 'https://api.github.com/users/LakshmanKishore/followers',
#    'following_url': 'https://api.github.com/users/LakshmanKishore/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LakshmanKishore/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LakshmanKishore/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LakshmanKishore/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LakshmanKishore/orgs',
#    'repos_url': 'https://api.github.com/users/LakshmanKishore/repos',
#    'events_url': 'https://api.github.com/users/LakshmanKishore/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LakshmanKishore/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-03T12:29:31Z',
#   'updated_at': '2024-02-03T12:29:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57223',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57223',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57223.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57223.patch',
#    'merged_at': None},
#   'body': '...themes\r\n\r\nReplaced the static pandas logo with a `picture` tag that displays a different logo based on the color scheme. In light mode, the original logo is shown, while in dark mode, a white version of the logo is displayed for better visibility.\r\n\r\nIn GitHub Dark Theme\r\n![image](https://github.com/pandas-dev/pandas/assets/61258323/a820a065-29d9-489a-b6f8-1e9d68bb5e57)\r\n\r\nIn GitHub Light Theme\r\n![image](https://github.com/pandas-dev/pandas/assets/61258323/66ff39ee-8f6f-4271-9cf6-16d7ba229717)\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57223/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57223/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57222',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57222/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57222/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57222/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57222',
#   'id': 2116253943,
#   'node_id': 'PR_kwDOAA0YD85l502b',
#   'number': 57222,
#   'title': 'ENH: Add all warnings check to the assert_produces_warnings, and separate messages for each warning.',
#   'user': {'login': 'Jorewin',
#    'id': 56088851,
#    'node_id': 'MDQ6VXNlcjU2MDg4ODUx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56088851?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jorewin',
#    'html_url': 'https://github.com/Jorewin',
#    'followers_url': 'https://api.github.com/users/Jorewin/followers',
#    'following_url': 'https://api.github.com/users/Jorewin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jorewin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jorewin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jorewin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jorewin/orgs',
#    'repos_url': 'https://api.github.com/users/Jorewin/repos',
#    'events_url': 'https://api.github.com/users/Jorewin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jorewin/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-03T05:30:15Z',
#   'updated_at': '2024-02-03T20:23:50Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57222',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57222',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57222.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57222.patch',
#    'merged_at': None},
#   'body': "The function in question gets used in multiple places, that's why I felt it would be safer to preserve current behavior and API, and add an additional, optional parameter, which alters the behavior, enabling checking if all passed warning types get detected.\r\n\r\n- [x] closes #56555 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57222/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57222/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57216',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57216/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57216/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57216/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57216',
#   'id': 2115839284,
#   'node_id': 'I_kwDOAA0YD85-HSU0',
#   'number': 57216,
#   'title': 'ENH: In sort methods, accept sequence or dict as key',
#   'user': {'login': 'gsehrlich',
#    'id': 11000354,
#    'node_id': 'MDQ6VXNlcjExMDAwMzU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11000354?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gsehrlich',
#    'html_url': 'https://github.com/gsehrlich',
#    'followers_url': 'https://api.github.com/users/gsehrlich/followers',
#    'following_url': 'https://api.github.com/users/gsehrlich/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gsehrlich/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gsehrlich/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gsehrlich/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gsehrlich/orgs',
#    'repos_url': 'https://api.github.com/users/gsehrlich/repos',
#    'events_url': 'https://api.github.com/users/gsehrlich/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gsehrlich/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1218227310,
#     'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index',
#     'name': 'Index',
#     'color': 'e99695',
#     'default': False,
#     'description': 'Related to the Index class or subclasses'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 6323552771,
#     'node_id': 'LA_kwDOAA0YD88AAAABeOnCAw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Sorting',
#     'name': 'Sorting',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'e.g. sort_index, sort_values'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-02-02T21:37:00Z',
#   'updated_at': '2024-02-02T23:09:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\r\n\r\n- [X] Adding new functionality to pandas\r\n\r\n- [ ] Changing existing functionality in pandas\r\n\r\n- [ ] Removing existing functionality in pandas\r\n\r\n\r\n### Problem Description\r\n\r\nPretty much every time I use the `key` kwarg of a pandas sort method, I use it to tell pandas the desired order of the unique values. For example:\r\n```python\r\nimport pandas as pd\r\n\r\nmy_index = pd.Index(['one', 'two', 'three', 'three', 'two', 'one', 'three'])\r\nmy_index.sort_values(\r\n    key=lambda idx: (idx\r\n        .to_series()\r\n        .rename(index={'one': 1, 'two': 2, 'three': 3})\r\n        .index\r\n    )\r\n)\r\n```\r\nThis is all a bit redundant, and I suspect it's a common use case.\r\n\r\nRelatedly, sometimes I want to use a different key function for different columns/levels. In order to do that, I actually need to call the sort method multiple times.\r\n\r\n### Feature Description\r\n\r\nAccept sequences like `['one', 'two', 'three']` specifying the ascending order of the values.\r\n\r\nEDIT: Example equivalent to the `sort_values` call above:\r\n\r\n```python\r\nmy_index.sort_values(key=['one', 'two', 'three'])\r\n```\r\n\r\nAlso accept dictionaries like `{'col_1': ['one', 'two', 'three'], 'col_3': my_sort_fn}` to sort different columns or levels with different keys in any format.\r\n\r\n### Alternative Solutions\r\n\r\nMake sure all data that I want to lexsort is always an ordered Categorical.\r\n\r\n### Additional Context\r\n\r\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57216/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57216/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57215',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57215/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57215/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57215/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57215',
#   'id': 2115764905,
#   'node_id': 'I_kwDOAA0YD85-HAKp',
#   'number': 57215,
#   'title': 'BUG: Error when trying to use `pd.date_range`',
#   'user': {'login': 'khider',
#    'id': 11758571,
#    'node_id': 'MDQ6VXNlcjExNzU4NTcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11758571?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/khider',
#    'html_url': 'https://github.com/khider',
#    'followers_url': 'https://api.github.com/users/khider/followers',
#    'following_url': 'https://api.github.com/users/khider/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/khider/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/khider/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/khider/subscriptions',
#    'organizations_url': 'https://api.github.com/users/khider/orgs',
#    'repos_url': 'https://api.github.com/users/khider/repos',
#    'events_url': 'https://api.github.com/users/khider/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/khider/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-02T20:39:36Z',
#   'updated_at': '2024-02-02T20:39:36Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport numpy as np\r\n\r\npd.date_range(start = np.datetime64(\'500000000-01-01\', \'s\'), end = np.datetime64(\'1500000000-01-01\', \'s\'), freq=\'1000000000YS-JAN\', unit=\'s\')\n```\n\n\n### Issue Description\n\nError:\r\n raise ValueError(f"Offset {offset} did not increment date")\r\n\r\nValueError: Offset <YearBegin: month=1> did not increment date\r\n\r\n\n\n### Expected Behavior\n\nCreate my date range\n\n### Installed Versions\n\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : fd3f57170aa1af588ba877e8e28c158a20a4886d\r\npython                : 3.11.7.final.0\r\npython-bits           : 64\r\nOS                    : Darwin\r\nOS-release            : 23.1.0\r\nVersion               : Darwin Kernel Version 23.1.0: Mon Oct  9 21:32:11 PDT 2023; root:xnu-10002.41.9~7/RELEASE_ARM64_T6030\r\nmachine               : arm64\r\nprocessor             : arm\r\nbyteorder             : little\r\nLC_ALL                : en_US.UTF-8\r\nLANG                  : en_US.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas                : 2.2.0\r\nnumpy                 : 1.26.3\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 68.2.2\r\npip                   : 23.3.1\r\nCython                : None\r\npytest                : 8.0.0\r\nhypothesis            : None\r\nsphinx                : 5.0.2\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.2\r\nIPython               : 8.20.0\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.2\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : None\r\ngcsfs                 : None\r\nmatplotlib            : 3.8.2\r\nnumba                 : 0.58.1\r\nnumexpr               : None\r\nodfpy                 : None\r\nopenpyxl              : None\r\npandas_gbq            : None\r\npyarrow               : 15.0.0\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : 1.12.0\r\nsqlalchemy            : None\r\ntables                : None\r\ntabulate              : 0.9.0\r\nxarray                : None\r\nxlrd                  : 2.0.1\r\nzstandard             : None\r\ntzdata                : 2023.4\r\nqtpy                  : 2.4.1\r\npyqt5                 : None\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57215/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57215/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57214',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57214/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57214/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57214/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57214',
#   'id': 2115685556,
#   'node_id': 'I_kwDOAA0YD85-Gsy0',
#   'number': 57214,
#   'title': 'ENH: pd.Series.str.isempty() to check for empty strings',
#   'user': {'login': 'michaelquinn32',
#    'id': 3473921,
#    'node_id': 'MDQ6VXNlcjM0NzM5MjE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3473921?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/michaelquinn32',
# ...
#   'labels': [{'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'pandas objects compatability with Numpy or Python functions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/116',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116/labels',
#    'id': 10403366,
#    'node_id': 'MI_kwDOAA0YD84Anr4m',
#    'number': 116,
#    'title': '2.2.1',
#    'description': 'on-merge: backport to 2.2.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 41,
#    'closed_issues': 69,
#    'state': 'open',
#    'created_at': '2024-01-11T01:47:31Z',
#    'updated_at': '2024-02-04T03:08:15Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-01-31T13:54:14Z',
#   'updated_at': '2024-02-01T17:17:54Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57172',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57172',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57172.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57172.patch',
#    'merged_at': None},
#   'body': 'Hi! \r\n\r\nThis PR addresses changes planned for NumPy in https://github.com/numpy/numpy/pull/25168 (new `copy` keyword for `np.asarray` and `np.array`).\r\n\r\n`np.array(..., copy=False)` will now throw and exception if a copy is needed. To retain the same behavior `np.asarray(...)` can be used, so a copy is made only when needed.\r\n\r\nI applied changes in a backward-compatible way, so that no NumPy version check & branching is needed.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57172/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57172/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57171',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57171/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57171/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57171/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57171',
#   'id': 2110030660,
#   'node_id': 'I_kwDOAA0YD859xINE',
#   'number': 57171,
#   'title': 'BUG: does .any(axis=1, skipna=False) follow Kleene Logic?',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-01-31T12:52:14Z',
#   'updated_at': '2024-02-01T22:27:18Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nIn [16]: pd.DataFrame({\r\n    ...:     'a': [True, False, None],\r\n    ...:     'b': [None, None, None],\r\n    ...: }, dtype='boolean[pyarrow]').any(axis=1, skipna=False)\r\nOut[16]:\r\n0     True  #\r\n1    False  # <=== should be NA?\r\n2    False  # <=== should be NA?\r\ndtype: bool[pyarrow]\r\n\r\n\r\nIn [17]: pd.Series([False, None], dtype='boolean[pyarrow]').any(skipna=False)\r\nOut[17]: <NA>\r\n\r\nIn [18]: pd.Series([None, None], dtype='boolean[pyarrow]').any(skipna=False)\r\nOut[18]: <NA>\r\n\r\nIn [19]: pd.Series([True, None], dtype='boolean[pyarrow]').any(skipna=False)\r\nOut[19]: True\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nI don't really understand what's happening, nor what's meant to be happening\r\n\r\n[The docs for `Series.any`](https://pandas.pydata.org/docs/reference/api/pandas.Series.any.html#pandas.Series.any) say\r\n\r\n> If skipna is False, then NA are treated as True, because these are not equal to zero.\r\n\r\nbut that doesn't seem to be the case. If that was the case, then\r\n```python\r\npd.Series([False, None], dtype='boolean[pyarrow]').any(skipna=False)\r\n```\r\nwould return `True`?\r\n\r\nInstead, it looks like `Series.any` follows Kleene Logic. Fair nuff - but then, `DataFrame.any(axis=1, skipna=False)` doesn't?\r\n\r\n### Expected Behavior\r\n\r\nI think I'd expect\r\n```python\r\n0     True\r\n1     <NA>\r\n2     <NA>\r\n```\r\nfrom the `DataFrame.any(axis=1, skipna=False)` example\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : fd3f57170aa1af588ba877e8e28c158a20a4886d\r\npython                : 3.10.12.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 5.15.133.1-microsoft-standard-WSL2\r\nVersion               : #1 SMP Thu Oct 5 21:02:42 UTC 2023\r\nmachine               : x86_64\r\nprocessor             : x86_64\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_GB.UTF-8\r\nLOCALE                : en_GB.UTF-8\r\n\r\npandas                : 2.2.0\r\nnumpy                 : 1.26.3\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 59.6.0\r\npip                   : 22.0.2\r\nCython                : None\r\npytest                : 7.4.4\r\nhypothesis            : None\r\nsphinx                : None\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.2\r\nIPython               : 8.19.0\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.2\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : 2023.12.2\r\ngcsfs                 : 2023.12.2post1\r\nmatplotlib            : None\r\nnumba                 : None\r\nnumexpr               : None\r\nodfpy                 : None\r\nopenpyxl              : None\r\npandas_gbq            : None\r\npyarrow               : 15.0.0\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : 1.11.4\r\nsqlalchemy            : 2.0.25\r\ntables                : None\r\ntabulate              : 0.9.0\r\nxarray                : None\r ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57171/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57171/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57170',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57170/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57170/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57170/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57170',
#   'id': 2109994385,
#   'node_id': 'PR_kwDOAA0YD85lkLDb',
#   'number': 57170,
#   'title': 'REGR: Series.astype raising TypeError when converting a pyarrow integer type with nulls to numpy float',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/116',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116/labels',
#    'id': 10403366,
#    'node_id': 'MI_kwDOAA0YD84Anr4m',
#    'number': 116,
#    'title': '2.2.1',
#    'description': 'on-merge: backport to 2.2.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 41,
#    'closed_issues': 69,
#    'state': 'open',
#    'created_at': '2024-01-11T01:47:31Z',
#    'updated_at': '2024-02-04T03:08:15Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-01-31T12:31:12Z',
#   'updated_at': '2024-02-01T17:19:09Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57170',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57170',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57170.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57170.patch',
#    'merged_at': None},
#   'body': '- [x] closes #57093\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.2.1.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57170/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57170/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
print(type(Json_via_request_AsList))
print(len(Json_via_request_AsList))
# Out:
# <class 'list'>
# 30

# %%
for data in range(len(Json_via_request_AsList)):
    print(Json_via_request_AsList[data]["user"]["node_id"])
# Out:
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjc5ODk3OTg=
# MDQ6VXNlcjMzOTk5MzI1
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjEwNjQ3MDgy
# U_kgDOCMI7PA
# MDQ6VXNlcjYxMjU4MzIz
# MDQ6VXNlcjU2MDg4ODUx
# MDQ6VXNlcjExMDAwMzU0
# MDQ6VXNlcjExNzU4NTcx
# MDQ6VXNlcjM0NzM5MjE=
# U_kgDOBmdpUw
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjE5NTMzODI=
# MDQ6VXNlcjQxNzM1MzEx
# MDQ6VXNlcjc5MTIyODk=
# MDQ6VXNlcjQ3MDMyNTYz
# MDQ6VXNlcjU2OTE0ODIw
# MDQ6VXNlcjgyOTYzMzE=
# MDQ6VXNlcjE5NDc3ODY0
# MDQ6VXNlcjIyMzg1Mzcx
# MDQ6VXNlcjI1MjAzNjU1
# MDQ6VXNlcjI1MjAzNjU1
# U_kgDOCLOEtQ
# MDQ6VXNlcjI4MzM4MzY=
# MDQ6VXNlcjg0MzExNTk=
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjg1MTk1MjM=

# %%
Json_via_request_DataFrame = pd.DataFrame(Json_via_request_AsList)
Json_via_request_DataFrame
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/57241  2116847445
# 1     https://github.com/pandas-dev/pandas/pull/57239  2116792327
# 2     https://github.com/pandas-dev/pandas/pull/57236  2116744441
# 3     https://github.com/pandas-dev/pandas/pull/57235  2116717762
# 4     https://github.com/pandas-dev/pandas/pull/57233  2116710632
# 5     https://github.com/pandas-dev/pandas/pull/57231  2116701137
# 6     https://github.com/pandas-dev/pandas/pull/57226  2116622677
# 7     https://github.com/pandas-dev/pandas/pull/57223  2116463548
# 8     https://github.com/pandas-dev/pandas/pull/57222  2116253943
# 9   https://github.com/pandas-dev/pandas/issues/57216  2115839284
# 10  https://github.com/pandas-dev/pandas/issues/57215  2115764905
# 11  https://github.com/pandas-dev/pandas/issues/57214  2115685556
# 12  https://github.com/pandas-dev/pandas/issues/57213  2115536364
# 13    https://github.com/pandas-dev/pandas/pull/57212  2114982768
# 14    https://github.com/pandas-dev/pandas/pull/57205  2113909202
# 15    https://github.com/pandas-dev/pandas/pull/57204  2113870822
# 16  https://github.com/pandas-dev/pandas/issues/57197  2113253877
# 17  https://github.com/pandas-dev/pandas/issues/57196  2112713037
# 18    https://github.com/pandas-dev/pandas/pull/57193  2112219935
# 19  https://github.com/pandas-dev/pandas/issues/57192  2112052708
# 20  https://github.com/pandas-dev/pandas/issues/57191  2111600616
# 21  https://github.com/pandas-dev/pandas/issues/57189  2111162868
# 22  https://github.com/pandas-dev/pandas/issues/57188  2111108717
# 23    https://github.com/pandas-dev/pandas/pull/57184  2110992084
# 24    https://github.com/pandas-dev/pandas/pull/57182  2110869914
# 25  https://github.com/pandas-dev/pandas/issues/57178  2110602795
# 26  https://github.com/pandas-dev/pandas/issues/57177  2110496397
# 27    https://github.com/pandas-dev/pandas/pull/57172  2110147542
# 28  https://github.com/pandas-dev/pandas/issues/57171  2110030660
# 29    https://github.com/pandas-dev/pandas/pull/57170  2109994385
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85l7yjQ   57241
# 1   PR_kwDOAA0YD85l7mRn   57239
# 2   PR_kwDOAA0YD85l7beW   57236
# 3   PR_kwDOAA0YD85l7VXe   57235
# 4   PR_kwDOAA0YD85l7UKJ   57233
# 5   PR_kwDOAA0YD85l7Sdw   57231
# 6   PR_kwDOAA0YD85l7DRf   57226
# 7   PR_kwDOAA0YD85l6iHK   57223
# 8   PR_kwDOAA0YD85l502b   57222
# 9    I_kwDOAA0YD85-HSU0   57216
# 10   I_kwDOAA0YD85-HAKp   57215
# 11   I_kwDOAA0YD85-Gsy0   57214
# 12   I_kwDOAA0YD85-GIXs   57213
# 13  PR_kwDOAA0YD85l1aX0   57212
# 14  PR_kwDOAA0YD85lxtUd   57205
# 15  PR_kwDOAA0YD85lxlJ9   57204
# 16   I_kwDOAA0YD8599bH1   57197
# 17   I_kwDOAA0YD8597XFN   57196
# 18  PR_kwDOAA0YD85lr1qK   57193
# 19   I_kwDOAA0YD859413k   57192
# 20   I_kwDOAA0YD8593Hfo   57191
# 21   I_kwDOAA0YD8591cn0   57189
# 22   I_kwDOAA0YD8591PZt   57188
# 23  PR_kwDOAA0YD85lnmxW   57184
# 24  PR_kwDOAA0YD85lnMPF   57182
# 25   I_kwDOAA0YD859zT4r   57178
# 26   I_kwDOAA0YD859y56N   57177
# 27  PR_kwDOAA0YD85lks5n   57172
# 28   I_kwDOAA0YD859xINE   57171
# 29  PR_kwDOAA0YD85lkLDb   57170
#
#                                                 title  ... closed_at  \
# 0   DEPR: Remove sql.execute, *args/**kwargs in re...  ...      None
# 1   DOC: fix PR02 errors in docstring for pandas.S...  ...      None
# 2            DOC: Clarifying brackets vs. parentheses  ...      None
# 3               DOC: Updated docstring for set_option  ...      None
# 4   REGR: Fix to_numpy conversion for arrow ea wit...  ...      None
# 5         DEPR: Remove Index type checking attributes  ...      None
# 6   WEB: Using Bootstrap icon instead of font awes...  ...      None
# 7   DOC: Replace pandas logo with a conditional im...  ...      None
# 8   ENH: Add all warnings check to the assert_prod...  ...      None
# 9   ENH: In sort methods, accept sequence or dict ...  ...      None
# 10      BUG: Error when trying to use `pd.date_range`  ...      None
# 11  ENH: pd.Series.str.isempty() to check for empt...  ...      None
# 12  BUG: to_numeric loses precision when convertin...  ...      None
# 13  BUG: ensure_string_array might modify read-onl...  ...      None
# 14  PERF: Avoid Series constructor in DataFrame(di...  ...      None
# 15  PDEP-14: Publish translations of pandas.pydata...  ...      None
# 16             BUG: ValueError: Invalid frequency: ME  ...      None
# 17  BUG: Dataframe's `to_sql` method fails while t...  ...      None
# 18  BUG: fix bug in DataFrame.diff when dataframe ...  ...      None
# 19  BUG: pandas 2.2.0 `DataFrame.groupby` regressi...  ...      None
# 20  ENH: deprecate reading from clipboard only sup...  ...      None
# 21  BUG: Series.map() coerces Int64Dtype and int64...  ...      None
# 22            ENH: align timedelta fractional seconds  ...      None
# 23                   Use ruff to detect banned import  ...      None
# 24                         Bump ruff to version 0.2.0  ...      None
# 25  ENH: Not silently ignore violation of minimal ...  ...      None
# 26  ENH: Expose integer formatting also for defaul...  ...      None
# 27  MAINT: Adjust the codebase to the new `np.arra...  ...      None
# 28  BUG: does .any(axis=1, skipna=False) follow Kl...  ...      None
# 29  REGR: Series.astype raising TypeError when con...  ...      None
#
#    author_association active_lock_reason  draft  \
# 0              MEMBER               None  False
# 1         CONTRIBUTOR               None  False
# 2                NONE               None  False
# 3         CONTRIBUTOR               None  False
# 4              MEMBER               None  False
# 5              MEMBER               None  False
# 6                NONE               None  False
# 7                NONE               None  False
# 8                NONE               None  False
# 9                NONE               None    NaN
# 10               NONE               None    NaN
# 11               NONE               None    NaN
# 12               NONE               None    NaN
# 13             MEMBER               None  False
# 14             MEMBER               None  False
# 15               NONE               None  False
# 16               NONE               None    NaN
# 17               NONE               None    NaN
# 18        CONTRIBUTOR               None  False
# 19               NONE               None    NaN
# 20               NONE               None    NaN
# 21               NONE               None    NaN
# 22        CONTRIBUTOR               None    NaN
# 23        CONTRIBUTOR               None  False
# 24        CONTRIBUTOR               None  False
# 25               NONE               None    NaN
# 26        CONTRIBUTOR               None    NaN
# 27        CONTRIBUTOR               None  False
# 28             MEMBER               None    NaN
# 29             MEMBER               None  False
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25                                                NaN
# 26                                                NaN
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0                                                None
# 1   All PR02 Errors resolved in the following case...
# 2   - [x] closes #56972\r\n- [ ] All [code checks ...
# 3   - [X] closes #57148\r\n- [X] [Tests added and ...
# 4   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 5   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 6   Closes https://github.com/pandas-dev/pandas/is...
# 7   ...themes\r\n\r\nReplaced the static pandas lo...
# 8   The function in question gets used in multiple...
# 9   ### Feature Type\r\n\r\n- [X] Adding new funct...
# 10  ### Pandas version checks\n\n- [X] I have chec...
# 11  ### Feature Type\n\n- [X] Adding new functiona...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  We ran into this in Dask, it's quite the edge ...
# 14  - [ ] closes #24368 (Replace xxxx with the Git...
# 15  Following up on the discussion in #56301, this...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  ### Pandas version checks\n\n- [X] I have chec...
# 18  supersede #53248\r\n\r\n- [x] closes #52579 (R...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 21  ### Pandas version checks\r\n\r\n- [X] I have ...
# 22  ### Feature Type\r\n\r\n- [X] Adding new funct...
# 23  There are several other potential replacement,...
# 24  Hi @mroeschke, while looking into the `pylint`...
# 25  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 26  ### Feature Type\r\n\r\n- [X] Adding new funct...
# 27  Hi! \r\n\r\nThis PR addresses changes planned ...
# 28  ### Pandas version checks\r\n\r\n- [X] I have ...
# 29  - [x] closes #57093\r\n- [x] [Tests added and ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                      None         None
# 1                      None         None
# 2                      None         None
# 3                      None         None
# 4                      None         None
# 5                      None         None
# 6                      None         None
# 7                      None         None
# 8                      None         None
# 9                      None         None
# 10                     None         None
# 11                     None         None
# 12                     None         None
# 13                     None         None
# 14                     None         None
# 15                     None         None
# 16                     None         None
# 17                     None         None
# 18                     None         None
# 19                     None         None
# 20                     None         None
# 21                     None         None
# 22                     None         None
# 23                     None         None
# 24                     None         None
# 25                     None         None
# 26                     None         None
# 27                     None         None
# 28                     None         None
# 29                     None         None
#
# [30 rows x 30 columns]

# %%
type(Json_via_request_DataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
Json_via_request_DataFrame.to_csv("json_full_data.csv")

# %%
Json_via_request_DataFrame["user"].to_csv("json_data_user_only.csv")

# %%
# Json_via_request_DataFrame["user"]["node_id"].to_csv("json_data_user_node_id_only.csv")
# giving error

# %%
# solving the dataset

dataFrame_CSV_Titanic = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")
dataFrame_CSV_Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
dataFrame_CSV_Titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataFrame_CSV_Titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dataFrame_CSV_Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dataFrame_CSV_Titanic.describe() # numerical data only 
# percentage of people below that number i.e. in Age: for 25 % on the ship 25% passenger is below or equal to 20 years of Age
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataFrame_CSV_Titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataFrame_CSV_Titanic[['PassengerId', 'Survived', 'Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
dataFrame_CSV_Titanic.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
object_column_index = dataFrame_CSV_Titanic.dtypes[dataFrame_CSV_Titanic.dtypes=="object"].index # get the columns which has type as object

# %%
len(object_column_index)
# Out:
# 5

# %%
# get the data frame for dtype = object
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic.dtypes[dataFrame_CSV_Titanic.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
# approach 2 : get the data frame for dtype = object
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic.columns[dataFrame_CSV_Titanic.dtypes=="object"]]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
# not object types
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic.columns[dataFrame_CSV_Titanic.dtypes!="object"]]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
# describe the object type data

# dataFrame_CSV_Titanic[dataFrame_CSV_Titanic.columns[dataFrame_CSV_Titanic.dtypes=="object"]].describe()
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic.dtypes[dataFrame_CSV_Titanic.dtypes=="object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# describe the not object type data

dataFrame_CSV_Titanic[dataFrame_CSV_Titanic.columns[dataFrame_CSV_Titanic.dtypes!="object"]].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataFrame_CSV_Titanic.describe(include="object") # once set include as object it shows description for object only
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
dataFrame_CSV_Titanic.describe(include=["object","float64"]) # once set include as object it shows description for object only
# Out:
#                            Name   Sex         Age  Ticket        Fare  \
# count                       891   891  714.000000     891  891.000000
# unique                      891     2         NaN     681         NaN
# top     Braund, Mr. Owen Harris  male         NaN  347082         NaN
# freq                          1   577         NaN       7         NaN
# mean                        NaN   NaN   29.699118     NaN   32.204208
# std                         NaN   NaN   14.526497     NaN   49.693429
# min                         NaN   NaN    0.420000     NaN    0.000000
# 25%                         NaN   NaN   20.125000     NaN    7.910400
# 50%                         NaN   NaN   28.000000     NaN   14.454200
# 75%                         NaN   NaN   38.000000     NaN   31.000000
# max                         NaN   NaN   80.000000     NaN  512.329200
#
#           Cabin Embarked
# count       204      889
# unique      147        3
# top     B96 B98        S
# freq          4      644
# mean        NaN      NaN
# std         NaN      NaN
# min         NaN      NaN
# 25%         NaN      NaN
# 50%         NaN      NaN
# 75%         NaN      NaN
# max         NaN      NaN

# %%
dataFrame_CSV_Titanic.describe(include="all") # once set include as all it shows description for all data type
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
dataFrame_CSV_Titanic.astype("object").describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
dataFrame_CSV_Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# slicing of data 
dataFrame_CSV_Titanic[1:10] # from 1 to 10 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
dataFrame_CSV_Titanic[1:10:2] # every alternate rows
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 5            6         0       3
# 7            8         0       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                   Moran, Mr. James    male   NaN      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 5      0    330877   8.4583   NaN        Q
# 7      1    349909  21.0750   NaN        S
# 9      0    237736  30.0708   NaN        C

# %%
# adding a new column
dataFrame_CSV_Titanic['new_column']="Avinash"

# %%
dataFrame_CSV_Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_column
# 0        0         A/5 21171   7.2500   NaN        S    Avinash
# 1        0          PC 17599  71.2833   C85        C    Avinash
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Avinash
# 3        0            113803  53.1000  C123        S    Avinash
# 4        0            373450   8.0500   NaN        S    Avinash
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S    Avinash
# 887      0            112053  30.0000   B42        S    Avinash
# 888      2        W./C. 6607  23.4500   NaN        S    Avinash
# 889      0            111369  30.0000  C148        C    Avinash
# 890      0            370376   7.7500   NaN        Q    Avinash
#
# [891 rows x 13 columns]

# %%
# adding two existing column to a new column

dataFrame_CSV_Titanic["family"] = dataFrame_CSV_Titanic["SibSp"]+dataFrame_CSV_Titanic["Parch"]
dataFrame_CSV_Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_column  family
# 0        0         A/5 21171   7.2500   NaN        S    Avinash       1
# 1        0          PC 17599  71.2833   C85        C    Avinash       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Avinash       0
# 3        0            113803  53.1000  C123        S    Avinash       1
# 4        0            373450   8.0500   NaN        S    Avinash       0
# ..     ...               ...      ...   ...      ...        ...     ...
# 886      0            211536  13.0000   NaN        S    Avinash       0
# 887      0            112053  30.0000   B42        S    Avinash       0
# 888      2        W./C. 6607  23.4500   NaN        S    Avinash       3
# 889      0            111369  30.0000  C148        C    Avinash       0
# 890      0            370376   7.7500   NaN        Q    Avinash       0
#
# [891 rows x 14 columns]

# %%
dataFrame_CSV_Titanic['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
# categorical function
pd.Categorical(dataFrame_CSV_Titanic['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(dataFrame_CSV_Titanic['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
dataFrame_CSV_Titanic['Cabin'].unique() # all unique value
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
dataFrame_CSV_Titanic['Cabin'].nunique()
# Out:
# 147

# %%
dataFrame_CSV_Titanic['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
dataFrame_CSV_Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_column  family
# 0        0         A/5 21171   7.2500   NaN        S    Avinash       1
# 1        0          PC 17599  71.2833   C85        C    Avinash       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Avinash       0
# 3        0            113803  53.1000  C123        S    Avinash       1
# 4        0            373450   8.0500   NaN        S    Avinash       0
# ..     ...               ...      ...   ...      ...        ...     ...
# 886      0            211536  13.0000   NaN        S    Avinash       0
# 887      0            112053  30.0000   B42        S    Avinash       0
# 888      2        W./C. 6607  23.4500   NaN        S    Avinash       3
# 889      0            111369  30.0000  C148        C    Avinash       0
# 890      0            370376   7.7500   NaN        Q    Avinash       0
#
# [891 rows x 14 columns]

# %%
# how may passenger are less than 5 year old

dataFrame_CSV_Titanic['Age']<=5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
# get the data for passenger < 5 years old
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Age']<=5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 58            59         1       2              West, Miss. Constance Mirium
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# 184          185         1       3       Kink-Heilmann, Miss. Luise Gretchen
# 193          194         1       2                Navratil, Master. Michel M
# 205          206         0       3                Strom, Miss. Telma Matilda
# 233          234         1       3            Asplund, Miss. Lillian Gertrud
# 261          262         1       3         Asplund, Master. Edvin Rojj Felix
# 297          298         0       1              Allison, Miss. Helen Loraine
# 305          306         1       1            Allison, Master. Hudson Trevor
# 340          341         1       2            Navratil, Master. Edmond Roger
# 348          349         1       3    Coutts, Master. William Loch "William"
# 374          375         0       3                Palsson, Miss. Stina Viola
# 381          382         1       3               Nakid, Miss. Maria ("Mary")
# 386          387         0       3           Goodwin, Master. Sidney Leonard
# 407          408         1       2            Richards, Master. William Rowe
# 445          446         1       1                 Dodge, Master. Washington
# 448          449         1       3            Baclini, Miss. Marie Catherine
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 479          480         1       3                  Hirvonen, Miss. Hildur E
# 530          531         1       2                  Quick, Miss. Phyllis May
# 618          619         1       2               Becker, Miss. Marion Louise
# 642          643         0       3             Skoog, Miss. Margit Elizabeth
# 644          645         1       3                    Baclini, Miss. Eugenie
# 691          692         1       3                        Karun, Miss. Manca
# 750          751         1       2                         Wells, Miss. Joan
# 755          756         1       2                 Hamalainen, Master. Viljo
# 777          778         1       3             Emanuel, Miss. Virginia Ethel
# 788          789         1       3                Dean, Master. Bertram Vere
# 803          804         1       3           Thomas, Master. Assad Alexander
# 824          825         0       3              Panula, Master. Urho Abraham
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 869          870         1       3           Johnson, Master. Harold Theodor
#
#         Sex   Age  SibSp  Parch           Ticket      Fare    Cabin Embarked  \
# 7      male  2.00      3      1           349909   21.0750      NaN        S
# 10   female  4.00      1      1          PP 9549   16.7000       G6        S
# 16     male  2.00      4      1           382652   29.1250      NaN        Q
# 43   female  3.00      1      2    SC/Paris 2123   41.5792      NaN        C
# 58   female  5.00      1      2       C.A. 34651   27.7500      NaN        S
# 63     male  4.00      3      2           347088   27.9000      NaN        S
# 78     male  0.83      0      2           248738   29.0000      NaN        S
# 119  female  2.00      4      2           347082   31.2750      NaN        S
# 164    male  1.00      4      1          3101295   39.6875      NaN        S
# 171    male  4.00      4      1           382652   29.1250      NaN        Q
# 172  female  1.00      1      1           347742   11.1333      NaN        S
# 183    male  1.00      2      1           230136   39.0000       F4        S
# 184  female  4.00      0      2           315153   22.0250      NaN        S
# 193    male  3.00      1      1           230080   26.0000       F2        S
# 205  female  2.00      0      1           347054   10.4625       G6        S
# 233  female  5.00      4      2           347077   31.3875      NaN        S
# 261    male  3.00      4      2           347077   31.3875      NaN        S
# 297  female  2.00      1      2           113781  151.5500  C22 C26        S
# 305    male  0.92      1      2           113781  151.5500  C22 C26        S
# 340    male  2.00      1      1           230080   26.0000       F2        S
# 348    male  3.00      1      1       C.A. 37671   15.9000      NaN        S
# 374  female  3.00      3      1           349909   21.0750      NaN        S
# 381  female  1.00      0      2             2653   15.7417      NaN        C
# 386    male  1.00      5      2          CA 2144   46.9000      NaN        S
# 407    male  3.00      1      1            29106   18.7500      NaN        S
# 445    male  4.00      0      2            33638   81.8583      A34        S
# 448  female  5.00      2      1             2666   19.2583      NaN        C
# 469  female  0.75      2      1             2666   19.2583      NaN        C
# 479  female  2.00      0      1          3101298   12.2875      NaN        S
# 530  female  2.00      1      1            26360   26.0000      NaN        S
# 618  female  4.00      2      1           230136   39.0000       F4        S
# 642  female  2.00      3      2           347088   27.9000      NaN        S
# 644  female  0.75      2      1             2666   19.2583      NaN        C
# 691  female  4.00      0      1           349256   13.4167      NaN        C
# 750  female  4.00      1      1            29103   23.0000      NaN        S
# 755    male  0.67      1      1           250649   14.5000      NaN        S
# 777  female  5.00      0      0           364516   12.4750      NaN        S
# 788    male  1.00      1      2        C.A. 2315   20.5750      NaN        S
# 803    male  0.42      0      1             2625    8.5167      NaN        C
# 824    male  2.00      4      1          3101295   39.6875      NaN        S
# 827    male  1.00      0      2  S.C./PARIS 2079   37.0042      NaN        C
# 831    male  0.83      1      1            29106   18.7500      NaN        S
# 850    male  4.00      4      2           347082   31.2750      NaN        S
# 869    male  4.00      1      1           347742   11.1333      NaN        S
#
#     new_column  family
# 7      Avinash       4
# 10     Avinash       2
# 16     Avinash       5
# 43     Avinash       3
# 58     Avinash       3
# 63     Avinash       5
# 78     Avinash       2
# 119    Avinash       6
# 164    Avinash       5
# 171    Avinash       5
# 172    Avinash       2
# 183    Avinash       3
# 184    Avinash       2
# 193    Avinash       2
# 205    Avinash       1
# 233    Avinash       6
# 261    Avinash       6
# 297    Avinash       3
# 305    Avinash       3
# 340    Avinash       2
# 348    Avinash       2
# 374    Avinash       4
# 381    Avinash       2
# 386    Avinash       7
# 407    Avinash       2
# 445    Avinash       2
# 448    Avinash       3
# 469    Avinash       3
# 479    Avinash       1
# 530    Avinash       2
# 618    Avinash       3
# 642    Avinash       5
# 644    Avinash       3
# 691    Avinash       1
# 750    Avinash       2
# 755    Avinash       2
# 777    Avinash       0
# 788    Avinash       3
# 803    Avinash       1
# 824    Avinash       5
# 827    Avinash       2
# 831    Avinash       2
# 850    Avinash       6
# 869    Avinash       2

# %%
len (dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Age']<=5])
# Out:
# 44

# %%
# no of passenger >18 years
len (dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Age']>18])
# Out:
# 575

# %%
# no of passenger <18 years old
# total - >18
len(dataFrame_CSV_Titanic)-len (dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Age']>18])
# len (dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Age']<=18])
# Out:
# 316

# %%
# how many passengers have paid less than avg. fare
dataFrame_CSV_Titanic['Fare'].mean()
# Out:
# 32.204207968574636

# %%
#dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']<32]

dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']<dataFrame_CSV_Titanic['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#     new_column  family
# 0      Avinash       1
# 2      Avinash       0
# 4      Avinash       0
# 5      Avinash       0
# 7      Avinash       4
# ..         ...     ...
# 886    Avinash       0
# 887    Avinash       0
# 888    Avinash       3
# 889    Avinash       0
# 890    Avinash       0
#
# [680 rows x 14 columns]

# %%
# less than avg
len(dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']<dataFrame_CSV_Titanic['Fare'].mean()])
# Out:
# 680

# %%
# more than avg
len(dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']>dataFrame_CSV_Titanic['Fare'].mean()])
# Out:
# 211

# %%
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 806          807         0       1            Andrews, Mr. Thomas Jr  male
# 815          816         0       1                  Fry, Mr. Richard  male
# 822          823         0       1   Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked new_column  family
# 179  36.0      0      0    LINE   0.0   NaN        S    Avinash       0
# 263  40.0      0      0  112059   0.0   B94        S    Avinash       0
# 271  25.0      0      0    LINE   0.0   NaN        S    Avinash       0
# 277   NaN      0      0  239853   0.0   NaN        S    Avinash       0
# 302  19.0      0      0    LINE   0.0   NaN        S    Avinash       0
# 413   NaN      0      0  239853   0.0   NaN        S    Avinash       0
# 466   NaN      0      0  239853   0.0   NaN        S    Avinash       0
# 481   NaN      0      0  239854   0.0   NaN        S    Avinash       0
# 597  49.0      0      0    LINE   0.0   NaN        S    Avinash       0
# 633   NaN      0      0  112052   0.0   NaN        S    Avinash       0
# 674   NaN      0      0  239856   0.0   NaN        S    Avinash       0
# 732   NaN      0      0  239855   0.0   NaN        S    Avinash       0
# 806  39.0      0      0  112050   0.0   A36        S    Avinash       0
# 815   NaN      0      0  112058   0.0  B102        S    Avinash       0
# 822  38.0      0      0   19972   0.0   NaN        S    Avinash       0

# %%
len(dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']==0])
# Out:
# 15

# %%
# name of the passenger who paid zero fare
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']==0].Name
# Out:
# 179                 Leonard, Mr. Lionel
# 263               Harrison, Mr. William
# 271        Tornquist, Mr. William Henry
# 277         Parkes, Mr. Francis "Frank"
# 302     Johnson, Mr. William Cahoone Jr
# 413      Cunningham, Mr. Alfred Fleming
# 466               Campbell, Mr. William
# 481    Frost, Mr. Anthony Wood "Archie"
# 597                 Johnson, Mr. Alfred
# 633       Parr, Mr. William Henry Marsh
# 674          Watson, Mr. Ennis Hastings
# 732                Knight, Mr. Robert J
# 806              Andrews, Mr. Thomas Jr
# 815                    Fry, Mr. Richard
# 822     Reuchlin, Jonkheer. John George
# Name: Name, dtype: object

# %%
# add the name to list
list(dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']==0].Name)
# Out:
# ['Leonard, Mr. Lionel',
#  'Harrison, Mr. William',
#  'Tornquist, Mr. William Henry',
#  'Parkes, Mr. Francis "Frank"',
#  'Johnson, Mr. William Cahoone Jr',
#  'Cunningham, Mr. Alfred Fleming',
#  'Campbell, Mr. William',
#  'Frost, Mr. Anthony Wood "Archie"',
#  'Johnson, Mr. Alfred',
#  'Parr, Mr. William Henry Marsh',
#  'Watson, Mr. Ennis Hastings',
#  'Knight, Mr. Robert J',
#  'Andrews, Mr. Thomas Jr',
#  'Fry, Mr. Richard',
#  'Reuchlin, Jonkheer. John George']

# %%
# how many passengers are male and female
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic["Sex"]=="male"]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_column  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S    Avinash
# 4    35.0      0      0            373450   8.0500   NaN        S    Avinash
# 5     NaN      0      0            330877   8.4583   NaN        Q    Avinash
# 6    54.0      0      0             17463  51.8625   E46        S    Avinash
# 7     2.0      3      1            349909  21.0750   NaN        S    Avinash
# ..    ...    ...    ...               ...      ...   ...      ...        ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S    Avinash
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S    Avinash
# 886  27.0      0      0            211536  13.0000   NaN        S    Avinash
# 889  26.0      0      0            111369  30.0000  C148        C    Avinash
# 890  32.0      0      0            370376   7.7500   NaN        Q    Avinash
#
#      family
# 0         1
# 4         0
# 5         0
# 6         0
# 7         4
# ..      ...
# 883       0
# 884       0
# 886       0
# 889       0
# 890       0
#
# [577 rows x 14 columns]

# %%
len(dataFrame_CSV_Titanic[dataFrame_CSV_Titanic["Sex"]=="male"])
# Out:
# 577

# %%
len(dataFrame_CSV_Titanic[dataFrame_CSV_Titanic["Sex"]=="female"])
# Out:
# 314

# %%
dataFrame_CSV_Titanic["Sex"].value_counts() # gives you all teh descriet values of Sex column
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# how many Survived
dataFrame_CSV_Titanic["Survived"].value_counts() # descriet values of Survived column
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# how many Survived in percentage
dataFrame_CSV_Titanic["Survived"].value_counts(normalize=True) # percent value
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
# how many females paid more than avg fare
dataFrame_CSV_Titanic[(dataFrame_CSV_Titanic["Sex"]=="female") & (dataFrame_CSV_Titanic['Fare']> dataFrame_CSV_Titanic['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch         Ticket      Fare Cabin Embarked new_column  family
# 1        0       PC 17599   71.2833   C85        C    Avinash       1
# 3        0         113803   53.1000  C123        S    Avinash       1
# 31       0       PC 17569  146.5208   B78        C    Avinash       1
# 43       2  SC/Paris 2123   41.5792   NaN        C    Avinash       3
# 52       0       PC 17572   76.7292   D33        C    Avinash       1
# ..     ...            ...       ...   ...      ...        ...     ...
# 853      1       PC 17592   39.4000   D28        S    Avinash       1
# 856      1          36928  164.8667   NaN        S    Avinash       2
# 863      2       CA. 2343   69.5500   NaN        S    Avinash      10
# 871      1          11751   52.5542   D35        S    Avinash       2
# 879      1          11767   83.1583   C50        C    Avinash       1
#
# [104 rows x 14 columns]

# %%
# how many male passenger are male or who paid more than avg fare >> or condition
dataFrame_CSV_Titanic[(dataFrame_CSV_Titanic["Sex"]=="male") | (dataFrame_CSV_Titanic["Fare"]> dataFrame_CSV_Titanic["Fare"].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_column  family
# 0        0         A/5 21171   7.2500   NaN        S    Avinash       1
# 1        0          PC 17599  71.2833   C85        C    Avinash       1
# 3        0            113803  53.1000  C123        S    Avinash       1
# 4        0            373450   8.0500   NaN        S    Avinash       0
# 5        0            330877   8.4583   NaN        Q    Avinash       0
# ..     ...               ...      ...   ...      ...        ...     ...
# 883      0  C.A./SOTON 34068  10.5000   NaN        S    Avinash       0
# 884      0   SOTON/OQ 392076   7.0500   NaN        S    Avinash       0
# 886      0            211536  13.0000   NaN        S    Avinash       0
# 889      0            111369  30.0000  C148        C    Avinash       0
# 890      0            370376   7.7500   NaN        Q    Avinash       0
#
# [681 rows x 14 columns]

# %%
np.mean(dataFrame_CSV_Titanic['Fare'])
# Out:
# 32.204207968574636

# %%
dataFrame_CSV_Titanic['Fare'].mean()
# Out:
# 32.204207968574636

# %%
max(dataFrame_CSV_Titanic['Fare'])
# Out:
# 512.3292

# %%
min(dataFrame_CSV_Titanic['Fare'])
# Out:
# 0.0

# %%
# who are the passenger who paid the max fare
dataFrame_CSV_Titanic[dataFrame_CSV_Titanic['Fare']==max(dataFrame_CSV_Titanic['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# how many passengers have parch than 3
# how many passengers who survived paid the maximum
# how many who did not survive was from class 1
# how many passengers are having children (<5  years old)

# %%
# Access data frame rows 
dataFrame_CSV_Titanic[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked new_column  family
# 0      0         A/5 21171   7.2500   NaN        S    Avinash       1
# 1      0          PC 17599  71.2833   C85        C    Avinash       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Avinash       0
# 3      0            113803  53.1000  C123        S    Avinash       1
# 4      0            373450   8.0500   NaN        S    Avinash       0
# 5      0            330877   8.4583   NaN        Q    Avinash       0
# 6      0             17463  51.8625   E46        S    Avinash       0
# 7      1            349909  21.0750   NaN        S    Avinash       4
# 8      2            347742  11.1333   NaN        S    Avinash       2
# 9      0            237736  30.0708   NaN        C    Avinash       1

# %%
dataFrame_CSV_Titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked new_column  family
# 0      0  A/5 21171  7.25   NaN        S    Avinash       1

# %%
# implicit index and explicit index
# implicit/integer index : generated by pandas
# explicit/named index : generated by you

# %%
# integer location
dataFrame_CSV_Titanic.iloc[0:2] # start from zero and go till 1 ~ upper limit -1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_column  family
# 0      0  A/5 21171   7.2500   NaN        S    Avinash       1
# 1      0   PC 17599  71.2833   C85        C    Avinash       1

# %%
# location named index 
dataFrame_CSV_Titanic.loc[0:2]# start from zero and go upper limit , give me all the rows whose name is 0,1,2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_column  family
# 0      0         A/5 21171   7.2500   NaN        S    Avinash       1
# 1      0          PC 17599  71.2833   C85        C    Avinash       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Avinash       0

# %%
#iloc requires numeric indexers, got ['Name' 'Sex' 'Age']
dataFrame_CSV_Titanic.iloc[0:2, [0,1,2]] # you can use named indexes but you can pass column internal indexes
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
dataFrame_CSV_Titanic.loc[0:2, ["Name","Sex","Age"]]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %%
# ["Name","Sex","Age"]
dataFrame_CSV_Titanic.iloc[0:2, [3,4,5]]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
dataFrame_CSV_Titanic.iloc[0:2,3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
dataFrame_CSV_Titanic[2:14]['Name']
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# Name: Name, dtype: object

# %%
dataFrame_CSV_Titanic['Name'][2:14]
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# Name: Name, dtype: object

# %%
len(dataFrame_CSV_Titanic['Name'][2:14])
# Out:
# 12

# %%
dataFrame_CSV_Titanic['Name'][2:5]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
list(dataFrame_CSV_Titanic['Name'][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s = pd.Series(list(dataFrame_CSV_Titanic['Name'][2:5]),index=["a","b","c"])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(dataFrame_CSV_Titanic['Name'][5:8]),index=["a","b","c"])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+s1 # series or data frame doesn't word with +
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
# s.append(s1)
pd.concat([s, s1])
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# a                                Moran, Mr. James
# b                         McCarthy, Mr. Timothy J
# c                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
dataFrame_CSV_Titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked new_column  family
# 0      0  A/5 21171  7.25   NaN        S    Avinash       1

# %%
# how to drop a column need to pass the axis
dataFrame_CSV_Titanic.drop('PassengerId',axis=1) # default axis is row wise
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#     new_column  family
# 0      Avinash       1
# 1      Avinash       1
# 2      Avinash       0
# 3      Avinash       1
# 4      Avinash       0
# ..         ...     ...
# 886    Avinash       0
# 887    Avinash       0
# 888    Avinash       3
# 889    Avinash       0
# 890    Avinash       0
#
# [891 rows x 13 columns]

# %%
dataFrame_CSV_Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_column  family
# 0        0         A/5 21171   7.2500   NaN        S    Avinash       1
# 1        0          PC 17599  71.2833   C85        C    Avinash       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Avinash       0
# 3        0            113803  53.1000  C123        S    Avinash       1
# 4        0            373450   8.0500   NaN        S    Avinash       0
# ..     ...               ...      ...   ...      ...        ...     ...
# 886      0            211536  13.0000   NaN        S    Avinash       0
# 887      0            112053  30.0000   B42        S    Avinash       0
# 888      2        W./C. 6607  23.4500   NaN        S    Avinash       3
# 889      0            111369  30.0000  C148        C    Avinash       0
# 890      0            370376   7.7500   NaN        Q    Avinash       0
#
# [891 rows x 14 columns]

# %%
dataFrame_CSV_Titanic.drop('PassengerId',axis=1, inplace=True) # inplace=True will modify the original data frame

# %%
dataFrame_CSV_Titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#     new_column  family
# 0      Avinash       1
# 1      Avinash       1
# 2      Avinash       0
# 3      Avinash       1
# 4      Avinash       0
# ..         ...     ...
# 886    Avinash       0
# 887    Avinash       0
# 888    Avinash       3
# 889    Avinash       0
# 890    Avinash       0
#
# [891 rows x 13 columns]

# %%
# drop a the first row
dataFrame_CSV_Titanic.drop(1,axis=0, inplace=True) # drop the first row
# dataFrame_CSV_Titanic.drop(1, inplace=True)
# how to drop a range of rows

# %%
dataFrame_CSV_Titanic
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_column  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S    Avinash
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    Avinash
# 3    35.0      1      0            113803  53.1000  C123        S    Avinash
# 4    35.0      0      0            373450   8.0500   NaN        S    Avinash
# 5     NaN      0      0            330877   8.4583   NaN        Q    Avinash
# ..    ...    ...    ...               ...      ...   ...      ...        ...
# 886  27.0      0      0            211536  13.0000   NaN        S    Avinash
# 887  19.0      0      0            112053  30.0000   B42        S    Avinash
# 888   NaN      1      2        W./C. 6607  23.4500   NaN        S    Avinash
# 889  26.0      0      0            111369  30.0000  C148        C    Avinash
# 890  32.0      0      0            370376   7.7500   NaN        Q    Avinash
#
#      family
# 0         1
# 2         0
# 3         1
# 4         0
# 5         0
# ..      ...
# 886       0
# 887       0
# 888       3
# 889       0
# 890       0
#
# [890 rows x 13 columns]

# %%
dataFrame_CSV_Titanic.set_index('Name',inplace=True)
#dataFrame_CSV_Titanic.set_index('Name')

# %%
dataFrame_CSV_Titanic
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss. Margaret Edith                         1       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"             0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
#                                               SibSp  Parch            Ticket  \
# Name
# Braund, Mr. Owen Harris                           1      0         A/5 21171
# Heikkinen, Miss. Laina                            0      0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0            113803
# Allen, Mr. William Henry                          0      0            373450
# Moran, Mr. James                                  0      0            330877
# ...                                             ...    ...               ...
# Montvila, Rev. Juozas                             0      0            211536
# Graham, Miss. Margaret Edith                      0      0            112053
# Johnston, Miss. Catherine Helen "Carrie"          1      2        W./C. 6607
# Behr, Mr. Karl Howell                             0      0            111369
# Dooley, Mr. Patrick                               0      0            370376
#
#                                                  Fare Cabin Embarked  \
# Name
# Braund, Mr. Owen Harris                        7.2500   NaN        S
# Heikkinen, Miss. Laina                         7.9250   NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123        S
# Allen, Mr. William Henry                       8.0500   NaN        S
# Moran, Mr. James                               8.4583   NaN        Q
# ...                                               ...   ...      ...
# Montvila, Rev. Juozas                         13.0000   NaN        S
# Graham, Miss. Margaret Edith                  30.0000   B42        S
# Johnston, Miss. Catherine Helen "Carrie"      23.4500   NaN        S
# Behr, Mr. Karl Howell                         30.0000  C148        C
# Dooley, Mr. Patrick                            7.7500   NaN        Q
#
#                                              new_column  family
# Name
# Braund, Mr. Owen Harris                         Avinash       1
# Heikkinen, Miss. Laina                          Avinash       0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)    Avinash       1
# Allen, Mr. William Henry                        Avinash       0
# Moran, Mr. James                                Avinash       0
# ...                                                 ...     ...
# Montvila, Rev. Juozas                           Avinash       0
# Graham, Miss. Margaret Edith                    Avinash       0
# Johnston, Miss. Catherine Helen "Carrie"        Avinash       3
# Behr, Mr. Karl Howell                           Avinash       0
# Dooley, Mr. Patrick                             Avinash       0
#
# [890 rows x 12 columns]

# %%
dataFrame_CSV_Titanic.loc['Allen, Mr. William Henry']
# Out:
# Survived            0
# Pclass              3
# Sex              male
# Age              35.0
# SibSp               0
# Parch               0
# Ticket         373450
# Fare             8.05
# Cabin             NaN
# Embarked            S
# new_column    Avinash
# family              0
# Name: Allen, Mr. William Henry, dtype: object

# %%
dataFrame_CSV_Titanic.iloc[1:2]
# Out:
#                         Survived  Pclass     Sex   Age  SibSp  Parch  \
# Name
# Heikkinen, Miss. Laina         1       3  female  26.0      0      0
#
#                                   Ticket   Fare Cabin Embarked new_column  \
# Name
# Heikkinen, Miss. Laina  STON/O2. 3101282  7.925   NaN        S    Avinash
#
#                         family
# Name
# Heikkinen, Miss. Laina       0

# %%
dataFrame_CSV_Titanic.iloc[1]
# Out:
# Survived                     1
# Pclass                       3
# Sex                     female
# Age                       26.0
# SibSp                        0
# Parch                        0
# Ticket        STON/O2. 3101282
# Fare                     7.925
# Cabin                      NaN
# Embarked                     S
# new_column             Avinash
# family                       0
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
dataFrame_CSV_Titanic.reset_index(inplace=True)

# %%
dataFrame_CSV_Titanic
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_column  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S    Avinash
# 1    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    Avinash
# 2    35.0      1      0            113803  53.1000  C123        S    Avinash
# 3    35.0      0      0            373450   8.0500   NaN        S    Avinash
# 4     NaN      0      0            330877   8.4583   NaN        Q    Avinash
# ..    ...    ...    ...               ...      ...   ...      ...        ...
# 885  27.0      0      0            211536  13.0000   NaN        S    Avinash
# 886  19.0      0      0            112053  30.0000   B42        S    Avinash
# 887   NaN      1      2        W./C. 6607  23.4500   NaN        S    Avinash
# 888  26.0      0      0            111369  30.0000  C148        C    Avinash
# 889  32.0      0      0            370376   7.7500   NaN        Q    Avinash
#
#      family
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
# ..      ...
# 885       0
# 886       0
# 887       3
# 888       0
# 889       0
#
# [890 rows x 13 columns]

# %%
# making data frame using dictionary
dec= {"key1":[2,3,4,5],
      "key2":[4,5,6,7],
      "key3":[2,3,4,5]}

# %%
dec
# Out:
# {'key1': [2, 3, 4, 5], 'key2': [4, 5, 6, 7], 'key3': [2, 3, 4, 5]}

# %%
pd.DataFrame(dec)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
df1 = pd.read_csv(r"C:\Users\avina\OneDrive\Documents\DataScience\Machine Leaning\taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# no. of null values
df1.isnull()
# Out:
#      taxonomy_id   name  parent_id  parent_name
# 0          False  False       True         True
# 1          False  False      False        False
# 2          False  False      False        False
# 3          False  False      False        False
# 4          False  False      False        False
# ..           ...    ...        ...          ...
# 285        False  False      False        False
# 286        False  False      False        False
# 287        False  False      False        False
# 288        False  False      False        False
# 289        False  False      False        False
#
# [290 rows x 4 columns]

# %%
df1.isnull().sum() # count of null value in each column
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1) # column will be dropped if value null is present as axis=1
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna("not value")
# Out:
#     taxonomy_id                          name  parent_id           parent_name
# 0           101                     Emergency  not value             not value
# 1        101-01             Disaster Response        101             Emergency
# 2        101-02                Emergency Cash        101             Emergency
# 3     101-02-01             Help Pay for Food     101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# ..          ...                           ...        ...                   ...
# 285   111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation        111                 Legal
# 287      111-03                        Notary        111                 Legal
# 288      111-04                Representation        111                 Legal
# 289      111-05  Translation & Interpretation        111                 Legal
#
# [290 rows x 4 columns]

# %%
dataFrame_CSV_Titanic
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_column  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S    Avinash
# 1    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    Avinash
# 2    35.0      1      0            113803  53.1000  C123        S    Avinash
# 3    35.0      0      0            373450   8.0500   NaN        S    Avinash
# 4     NaN      0      0            330877   8.4583   NaN        Q    Avinash
# ..    ...    ...    ...               ...      ...   ...      ...        ...
# 885  27.0      0      0            211536  13.0000   NaN        S    Avinash
# 886  19.0      0      0            112053  30.0000   B42        S    Avinash
# 887   NaN      1      2        W./C. 6607  23.4500   NaN        S    Avinash
# 888  26.0      0      0            111369  30.0000  C148        C    Avinash
# 889  32.0      0      0            370376   7.7500   NaN        Q    Avinash
#
#      family
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
# ..      ...
# 885       0
# 886       0
# 887       3
# 888       0
# 889       0
#
# [890 rows x 13 columns]

# %%
dataFrame_CSV_Titanic.dtypes
# Out:
# Name           object
# Survived        int64
# Pclass          int64
# Sex            object
# Age           float64
# SibSp           int64
# Parch           int64
# Ticket         object
# Fare          float64
# Cabin          object
# Embarked       object
# new_column     object
# family          int64
# dtype: object

# %%
dataFrame_CSV_Titanic.groupby('Survived').mean()
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_3780\2692289922.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataFrame_CSV_Titanic.groupby('Survived').mean()
#             Pclass        Age     SibSp     Parch       Fare    family
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887  0.883424
# 1         1.953079  28.310277  0.472141  0.466276  48.328288  0.938416

# %%
# what is the avg fare paid by passenger who survived ?
# group by
grouped  = dataFrame_CSV_Titanic.groupby('Pclass')['Pclass']
# grouped.sum()
grouped.mean()
# grouped.count()
# Out:
# Pclass
# 1    1.0
# 2    2.0
# 3    3.0
# Name: Pclass, dtype: float64

# %%
dataFrame_CSV_Titanic.groupby('Survived').aggregate(['min','max','mean','median','count'])
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_3780\3637607035.py:1: FutureWarning: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'new_column'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   dataFrame_CSV_Titanic.groupby('Survived').aggregate(['min','max','mean','median','count'])
#          Pclass                              Age                          \
#             min max      mean median count   min   max       mean median
# Survived
# 0             1   3  2.531876    3.0   549  1.00  74.0  30.626179   28.0
# 1             1   3  1.953079    2.0   341  0.42  80.0  28.310277   28.0
#
#                 ... Fare                                   family      \
#          count  ...  min       max       mean median count    min max
# Survived        ...
# 0          424  ...  0.0  263.0000  22.117887   10.5   549      0  10
# 1          289  ...  0.0  512.3292  48.328288   26.0   341      0   6
#
#
#               mean median count
# Survived
# 0         0.883424    0.0   549
# 1         0.938416    1.0   341
#
# [2 rows x 30 columns]

# %%
pd.__version__
# Out:
# '1.5.2'
