# %%
# matplotlib, seaborn >> important from interview, plotly >> interactive, bokeh

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# import matplotlib as mat

# %%
# mat.__version__

# %%
x= np.random.rand(50)
y= np.random.rand(50)

# %%
plt.scatter(x,y)

# %%
# pd.set_option("")
np.random.randn(10)

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['data'],index = pd.date_range('2020/04/21',periods=1000))

# %%
df.plot(figsize=(10,4)) # figure size

# %%
x = np.linspace(0, 10, 100)

# %%
x

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x),'--')

# %%
plt.plot(x, np.sin(x),'.')

# %%
plt.figure() # make a canvas
plt.subplot(1,2,1) # on the step 1 page , make sub plot and 2 plots and access the 1st plot
plt.plot(x, np.sin(x))

plt.subplot(1,2,2) # on the step 1 page , make sub plot and 2 plots and access the 2nd plot
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() # make a canvas
plt.subplot(2,2,1) # nrows, ncols:  create 2*2 plot and access the 1st plot
plt.plot(x, np.sin(x))

plt.subplot(2,2,2) # nrows, ncols:  create 2*2 plot and access the 2nd plot
plt.plot(x, np.cos(x))


plt.subplot(2,2,3) # nrows, ncols:  create 2*2 plot and access the 3rd plot
plt.plot(x, np.tan(x))

plt.subplot(2,2,4) # nrows, ncols:  create 2*2 plot and access the 4th plot
plt.plot(x, np.cos(x+1))

plt.show()

# %%
plt.figure() # make a canvas
plt.subplot(2,1,1) # # nrows, ncols: and access the 1st plot
plt.plot(x, np.sin(x))

plt.subplot(2,1,2) # # nrows, ncols: and access the 2nd plot
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.plot(x, np.sin(x-0), color='red')
plt.plot(x, np.sin(x-1), color='green')
plt.plot(x, np.sin(x-2), color=(1.0,0.5,0)) # rgb

# %%
# can we change the values of x and y axis 
plt.plot(x, np.sin(x-0), color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
# can we change the plot to cover all the empty space above 
plt.plot(x, np.sin(x-0), color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis("equal")
plt.show()

# %%
plt.figure() # make a canvas
plt.subplot(2,1,1) # on the step 1 page , make sub plot and 2 plots and access the 1st plot
plt.plot(x, np.sin(x-0), color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis("equal")
plt.show()

# %%
# how to put grid on the graph, put title, x label y label

plt.plot(x, np.sin(x-0), color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.title("sample title")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.axis("equal")
plt.show()

# %%
# how to put grid on the graph, put title, x label y label , legend

plt.plot(x, np.sin(x-0), color='blue', label = "Sinx")
plt.plot(x, np.cos(x-0), color='green', label = "Cosx")
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.title("sample title")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.axis("equal")
plt.legend()
plt.show()

# %%
# Histogram
data = np.random.randn(1000)
print(data)
plt.hist(data) # default bean size is 10 
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data,bins=20, histtype='bar', color='green') # default bean size is 10 change as 20
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([0.96357931, 0.33156219, 0.93821129, 0.17339914, 0.87970074,
#        0.17929117, 0.15508103, 0.55235449, 0.3145772 , 0.82406821,
#        0.35522495, 0.21959492, 0.8802901 , 0.6112021 , 0.60430792,
#        0.17925648, 0.61124626, 0.96375679, 0.49004193, 0.1312112 ,
#        0.04983734, 0.6835487 , 0.85246952, 0.06448751, 0.45311517,
#        0.38065059, 0.66935943, 0.30590816, 0.28829548, 0.40717631,
#        0.31400777, 0.54222202, 0.59729652, 0.94611848, 0.15382451,
#        0.78682303, 0.30157282, 0.79743629, 0.42467839, 0.34475585,
#        0.79892878, 0.56165998, 0.5479004 , 0.79560282, 0.4231571 ,
#        0.32878716, 0.49122998, 0.8431368 , 0.68617755, 0.97999518])

# %%
x= np.random.rand(50)
y= np.random.rand(50)
plt.figure(figsize=(6,2)) # size in inches
plt.scatter(x,y,c='red', alpha= .9, marker= "^")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("scatter plot")
plt.show()

# %%
x,y

# %%
x = ["a","b","c","d"] 
y= [3,4,1,6]

# %%
x,y
# Out:
# (['a', 'b', 'c', 'd'], [3, 4, 1, 6])

# %%
plt.figure(figsize=(6,3))
plt.bar(x,y, color='#ff7373')
plt.title("this is my bar plot")
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.barh(x,y, color='#ff7373') # to plot on horizontal axis
plt.title("this is my bar plot")
plt.show()

# %%
data = [1,2,3,3,3,3,3,4,4,4,5,5,5,5,6,7,8,9]
plt.hist(data)
plt.show()

# %%
# 3d plot
x =np.random.rand(20)
y =np.random.rand(20)
z =np.random.rand(20)
x,y,z

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z, c="#ff7373", alpha=.9)
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.show()

# %%
plt.figure()
plt.subplot(projection = '3d')
plt.scatter(x,y,z, c="#ff7373")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.show()

# %%
import pandas as pd

# %%
data = pd.read_csv("Bank Customer Churn Prediction.csv")
data.head(1)
# Out:
#    customer_id  credit_score country  gender  age  tenure  balance  \
# 0     15634602           619  France  Female   42       2      0.0
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1

# %%
data.plot.scatter(x="age",y="balance")

# insight
# maximum concentration >> 25 -50 year age
# minimum balance zero across all the age group
# Out:
# <Axes: xlabel='age', ylabel='balance'>

# %%
# age distribution
plt.title("Age distribution")
plt.hist(data["age"], color = "red")
plt.show()

# balance distribution
plt.title("Balance distribution")
plt.hist(data["balance"], color = "blue")
plt.show()
